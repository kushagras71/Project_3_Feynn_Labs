# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import normalize

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0               1                           1                11.28
# 1               2                           0                 9.75
# 2               3                           1                10.79
# 3               4                           0                11.00
# 4               5                           1                14.17
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                          0.90   34   23    1        1.0        0
# 1                          0.23   54   33    1        NaN        0
# 2                          0.91   70   49    0        NaN        0
# 3                          0.43   71   50    0        NaN        0
# 4                          0.83   52   19    0        NaN        0
#
#    Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
# 0              45961                     48071                          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Patient_Number                 2000 non-null   int64
#  1   Blood_Pressure_Abnormality     2000 non-null   int64
#  2   Level_of_Hemoglobin            2000 non-null   float64
#  3   Genetic_Pedigree_Coefficient   1908 non-null   float64
#  4   Age                            2000 non-null   int64
#  5   BMI                            2000 non-null   int64
#  6   Sex                            2000 non-null   int64
#  7   Pregnancy                      442 non-null    float64
#  8   Smoking                        2000 non-null   int64
#  9   Physical_activity              2000 non-null   int64
#  10  salt_content_in_the_diet       2000 non-null   int64
#  11  alcohol_consumption_per_day    1758 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# count     2000.000000                 2000.000000          2000.000000
# mean      1000.500000                    0.493500            11.710035
# std        577.494589                    0.500083             2.186701
# min          1.000000                    0.000000             8.100000
# 25%        500.750000                    0.000000            10.147500
# 50%       1000.500000                    0.000000            11.330000
# 75%       1500.250000                    1.000000            12.945000
# max       2000.000000                    1.000000            17.560000
#
#        Genetic_Pedigree_Coefficient          Age          BMI          Sex  \
# count                   1908.000000  2000.000000  2000.000000  2000.000000
# mean                       0.494817    46.558500    30.081500     0.496000
# std                        0.291736    17.107832    11.761208     0.500109
# ...

# %%
df.isnull().sum()
# Out:
# Patient_Number                      0
# Blood_Pressure_Abnormality          0
# Level_of_Hemoglobin                 0
# Genetic_Pedigree_Coefficient       92
# Age                                 0
# BMI                                 0
# Sex                                 0
# Pregnancy                        1558
# Smoking                             0
# Physical_activity                   0
# salt_content_in_the_diet            0
# alcohol_consumption_per_day       242
# Level_of_Stress                     0
# Chronic_kidney_disease              0
# Adrenal_and_thyroid_disorders       0
# dtype: int64

# %%
df = df.drop(['Patient_Number','Pregnancy'], axis = 1)

# %%
df.head()
# Out:
#    Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                           1                11.28
# 1                           0                 9.75
# 2                           1                10.79
# 3                           0                11.00
# 4                           1                14.17
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Smoking  Physical_activity  \
# 0                          0.90   34   23    1        0              45961
# 1                          0.23   54   33    1        0              26106
# 2                          0.91   70   49    0        0               9995
# 3                          0.43   71   50    0        0              10635
# 4                          0.83   52   19    0        0              15619
#
#    salt_content_in_the_diet  alcohol_consumption_per_day  Level_of_Stress  \
# 0                     48071                          NaN                2
# ...

# %%
sns.countplot(x='Blood_Pressure_Abnormality', data=df)
# Out:
# <AxesSubplot:xlabel='Blood_Pressure_Abnormality', ylabel='count'>

# %%
sns.countplot(x='Smoking', data=df)
# Out:
# <AxesSubplot:xlabel='Smoking', ylabel='count'>

# %%
sns.countplot(x='Level_of_Stress', data=df)
# Out:
# <AxesSubplot:xlabel='Level_of_Stress', ylabel='count'>

# %%
sns.countplot(x='Chronic_kidney_disease', data=df)
# Out:
# <AxesSubplot:xlabel='Chronic_kidney_disease', ylabel='count'>

# %%
sns.countplot(x='Adrenal_and_thyroid_disorders', data=df)
# Out:
# <AxesSubplot:xlabel='Adrenal_and_thyroid_disorders', ylabel='count'>

# %%
df = df.fillna(method="backfill")

# %%
df.isnull().sum()
# Out:
# Blood_Pressure_Abnormality       0
# Level_of_Hemoglobin              0
# Genetic_Pedigree_Coefficient     0
# Age                              0
# BMI                              0
# Sex                              0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# alcohol_consumption_per_day      0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# dtype: int64

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Using Elbow Method Cluster 2 can be best for segmentation.
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(df)

# %%
#create a column to visualize the cluster
df['Cluster'] = y_kmeans

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=df, x="Blood_Pressure_Abnormality", y="Age", hue="Cluster")
# Out:
# <AxesSubplot:xlabel='Blood_Pressure_Abnormality', ylabel='Age'>

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=df, x="Adrenal_and_thyroid_disorders", y="Age", hue="Cluster")
# Out:
# <AxesSubplot:xlabel='Adrenal_and_thyroid_disorders', ylabel='Age'>

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=df, x="Physical_activity", y="Age", hue="Cluster")
# Out:
# <AxesSubplot:xlabel='Physical_activity', ylabel='Age'>
